# %% [markdown]
# # Agentic Trip AI 90%
# Run this notebook to understand the files created in the project.

# %%
# Install dependencies
# !pip install -r requirements.txt

# %% [markdown]
# ## Project Structure
# - app.py
# - planner_agent.py
# - supervisor_agent.py
# - memory_agent.py
# - tools/kpi_tools.py
# - tools/report_tools.py
# - tools/rag_tools.py
# - tools/email_tools.py

# %%
import pandas as pd

df = pd.read_csv('sample_trip_data.csv')
df.head()
# Out:
#           Trip Status    Trip Remark     Vehicle Transporter Name       DI No  \
# 0      TRIP MONITORED   GEOFENCE HIT  KA01AB1234    ABC Logistics  6991579188
# 1      TRIP MONITORED  DEV (0-15) KM  KA02CD5678    XYZ Transport  6991579189
# 2             NDD-EPF        NDD-EPF  KA03EF9012    ABC Logistics  6991579190
# 3  TRIP NOT MONITORED   DATA LOSS 5%  KA04GH3456    PQR Roadlines  6991579191
# 4      TRIP MONITORED   GEOFENCE HIT  KA05IJ7890    XYZ Transport  6991579192
#
#   Customer Name Destination Onwards Travel Duration(Hrs.Mins)  \
# 0    Customer A   Bangalore                              8:30
# 1    Customer B       Hubli                             12:45
# 2    Customer C       Gadag                              0:00
# 3    Customer D      Koppal                              5:20
# 4    Customer E      Haveri                             15:10
#
#   Geofence Hit Miss Status Accountability
# 0                      HIT       Customer
# ...
